# %% [markdown]
# ## Generate Golden Dataset - V1
#
# ### About
# * Golden Dataset Scenario 1:
#   * Upload documents and queries
#   * Specify `top_k` as retrieved chunks
#   * query --> referenced context --> referenced answer
