# %% [markdown]
# ## Baseline Retrieval
#
# * For each query, retrieve the most relevant document

# %%
# %load_ext autoreload
# %autoreload 2

from datasets import load_dataset
from pprint import pprint

from llama_index.core import SimpleDirectoryReader
from llama_index.core.node_parser import SimpleNodeParser

import warnings
warnings.filterwarnings('ignore')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ### Load Raw Data

# %%
documents = SimpleDirectoryReader("../datasets/wix_docs").load_data()
print(len(documents))
# Out:
# 6221

# %%
# get number of tokens in each document

# %%
qa_ds = load_dataset("Wix/WixQA", "wixqa_expertwritten")
qa_corpous = load_dataset("Wix/WixQA", "wix_kb_corpus")
print(qa_ds.shape, qa_corpous.shape)

# %% [markdown]
# ### Basic Chunking

# %%
parser = SimpleNodeParser.from_defaults(
    chunk_size=500,    
    chunk_overlap=50
)

nodes = parser.get_nodes_from_documents(documents)
